# %% [markdown]
# ## list

# %%
lst = [1,2,3,"toi",5.7,1,1,1]
# for i, x in enumerate(lst, 1):
#     print(f"lst[{i}] = {x}")

# lst.append([1,2,5])
# print(lst)

# lst.insert(0,100)
# print(lst)

# lst = lst + [1,8,9,10]
# print(lst)

# lst.remove(1)
# print(lst)

# lst2 = lst 
# lst2[0] = 100
# print(lst2)
# print(lst)

lst2 = list(lst) #hoặc lst2 = lst.copy()
lst2[0] = 100
print(lst2)
print(lst)
# Out:
# [100, 2, 3, 'toi', 5.7, 1, 1, 1]
# [1, 2, 3, 'toi', 5.7, 1, 1, 1]

# %% [markdown]
# ## tuple

# %%
tup = (1,2,4,5,9.0,"32fd")
# lst = list(tup)
# lst[0] = 100
# tup = tuple(lst)
print(tup[0:6:2])
tup
# Out:
#   Cell In[21], line 6
#     del.tup(1)
#        ^
# SyntaxError: invalid syntax
